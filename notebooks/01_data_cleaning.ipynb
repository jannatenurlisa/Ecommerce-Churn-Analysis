# %%
import pandas as pd 
import numpy as np

# %%
#dataset load and read
df = pd.read_csv(r'F:\Projects\User Retention Study\User Churn Analysis\Data\raw\ecommarce_clickstream_transactions.csv')

# %%
print("Dataset Shape:", df.shape)
print("\nFirst few rows:")
print(df.head())
print("\nColumn names and types")
print(df.dtypes)
print("\nMissing values:")
print(df.isnull().sum())
print("\nBasic status:")
print(df.describe())
# Out:
# Dataset Shape: (74817, 7)
#
# First few rows:
#    UserID  SessionID                   Timestamp     EventType  ProductID  \
# 0       1          1  2024-07-07 18:00:26.959902     page_view        NaN
# 1       1          1  2024-03-05 22:01:00.072000     page_view        NaN
# 2       1          1  2024-03-23 22:08:10.568453  product_view  prod_8199
# 3       1          1  2024-03-12 00:32:05.495638   add_to_cart  prod_4112
# 4       1          1  2024-02-25 22:43:01.318876   add_to_cart  prod_3354
#
#    Amount Outcome
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
# Column names and types
# UserID         int64
# SessionID      int64
# Timestamp        str
# EventType        str
# ProductID        str
# Amount       float64
# Outcome          str
# dtype: object
#
# Missing values:
# UserID           0
# SessionID        0
# Timestamp        0
# EventType        0
# ProductID    42704
# Amount       64135
# Outcome      64135
# ...

# %%
#changing data typ from str to datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.dtypes
# Out:
# UserID                int64
# SessionID             int64
# Timestamp    datetime64[us]
# EventType               str
# ProductID               str
# Amount              float64
# Outcome                 str
# dtype: object

# %%
#count of each event 
df['EventType'].value_counts()
# Out:
# EventType
# page_view       10819
# add_to_cart     10735
# product_view    10696
# logout          10685
# purchase        10682
# click           10632
# login           10568
# Name: count, dtype: int64

# %%
#colimn insigth
df[df['Amount'].notnull()].head
# Out:
# <bound method NDFrame.head of        UserID  SessionID                  Timestamp EventType  ProductID  \
# 15          1          3 2024-03-15 05:22:41.094810  purchase  prod_5244
# 30          1          4 2024-07-15 16:15:52.074487  purchase  prod_9886
# 34          1          5 2024-01-19 16:51:29.413903  purchase  prod_6690
# 37          1          5 2024-06-27 07:40:55.374830  purchase  prod_9946
# 41          1          5 2024-04-10 13:43:05.891055  purchase  prod_5113
# ...       ...        ...                        ...       ...        ...
# 74803    1000          9 2024-05-19 08:23:54.724051  purchase  prod_2663
# 74807    1000          9 2024-03-20 02:45:31.128556  purchase  prod_9381
# 74811    1000         10 2024-04-20 20:35:42.737664  purchase  prod_7326
# 74812    1000         10 2024-05-11 22:48:45.500117  purchase  prod_1238
# 74815    1000         10 2024-04-30 16:19:48.002633  purchase  prod_2515
#
#            Amount   Outcome
# 15      72.913619  purchase
# ...

# %%
#sort dataset by time
df = df.sort_values(by='Timestamp')

# %%
print(df['Outcome'].value_counts(dropna=False))
# Out:
# Outcome
# NaN         64135
# purchase    10682
# Name: count, dtype: int64
